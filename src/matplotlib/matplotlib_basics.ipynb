# %% [markdown]
# # Matplotlib

# %%
import matplotlib.pyplot as plt
import numpy as np

# %%
x = np.linspace(1, 10, 100)

# %%
y = np.sin(x)

# %%
plt.xlabel('time')
plt.ylabel('sine')
plt.title('Sine Wave')
plt.plot(x, y)

# %%
plt.show()
